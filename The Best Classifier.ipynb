# %%
import pandas as pd
# %pwd
# Out:
# '/Users/sylvaincarlevato'

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %%
df = pd.read_csv("loan_train.csv")

# %%
print(df)
# Out:
#      Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0             0             0     PAIDOFF       1000     30       9/8/2016
# 1             2             2     PAIDOFF       1000     30       9/8/2016
# 2             3             3     PAIDOFF       1000     15       9/8/2016
# 3             4             4     PAIDOFF       1000     30       9/9/2016
# 4             6             6     PAIDOFF       1000     30       9/9/2016
# ..          ...           ...         ...        ...    ...            ...
# 341         394           394  COLLECTION        800     15      9/11/2016
# 342         395           395  COLLECTION       1000     30      9/11/2016
# 343         397           397  COLLECTION        800     15      9/12/2016
# 344         398           398  COLLECTION       1000     30      9/12/2016
# 345         399           399  COLLECTION       1000     30      9/12/2016
#
#        due_date  age             education  Gender
# 0     10/7/2016   45  High School or Below    male
# 1     10/7/2016   33              Bechalor  female
# 2     9/22/2016   27               college    male
# 3     10/8/2016   28               college  female
# 4     10/8/2016   29               college    male
# ..          ...  ...                   ...     ...
# 341   9/25/2016   32  High School or Below    male
# 342  10/10/2016   25  High School or Below    male
# 343   9/26/2016   39               college    male
# 344  11/10/2016   28               college    male
# 345  10/11/2016   26               college    male
#
# [346 rows x 10 columns]

# %%
pd.read_csv("loan_train.csv")
# Out:
#      Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0             0             0     PAIDOFF       1000     30       9/8/2016
# 1             2             2     PAIDOFF       1000     30       9/8/2016
# 2             3             3     PAIDOFF       1000     15       9/8/2016
# 3             4             4     PAIDOFF       1000     30       9/9/2016
# 4             6             6     PAIDOFF       1000     30       9/9/2016
# ..          ...           ...         ...        ...    ...            ...
# 341         394           394  COLLECTION        800     15      9/11/2016
# 342         395           395  COLLECTION       1000     30      9/11/2016
# 343         397           397  COLLECTION        800     15      9/12/2016
# 344         398           398  COLLECTION       1000     30      9/12/2016
# 345         399           399  COLLECTION       1000     30      9/12/2016
#
#        due_date  age             education  Gender
# 0     10/7/2016   45  High School or Below    male
# 1     10/7/2016   33              Bechalor  female
# 2     9/22/2016   27               college    male
# 3     10/8/2016   28               college  female
# 4     10/8/2016   29               college    male
# ..          ...  ...                   ...     ...
# 341   9/25/2016   32  High School or Below    male
# 342  10/10/2016   25  High School or Below    male
# 343   9/26/2016   39               college    male
# 344  11/10/2016   28               college    male
# 345  10/11/2016   26               college    male
#
# [346 rows x 10 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30       9/8/2016
# 1           2             2     PAIDOFF       1000     30       9/8/2016
# 2           3             3     PAIDOFF       1000     15       9/8/2016
# 3           4             4     PAIDOFF       1000     30       9/9/2016
# 4           6             6     PAIDOFF       1000     30       9/9/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   45  High School or Below    male
# 1  10/7/2016   33              Bechalor  female
# 2  9/22/2016   27               college    male
# 3  10/8/2016   28               college  female
# 4  10/8/2016   29               college    male

# %%
df.shape
# Out:
# (346, 10)

# %%
df.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1    Principal       terms         age
# count  346.000000    346.000000   346.000000  346.000000  346.000000
# mean   202.167630    202.167630   943.641618   22.653179   30.939306
# std    115.459715    115.459715   109.425530    7.991006    6.039418
# min      0.000000      0.000000   300.000000    7.000000   18.000000
# 25%    107.250000    107.250000   900.000000   15.000000   27.000000
# 50%    204.500000    204.500000  1000.000000   30.000000   30.000000
# 75%    298.750000    298.750000  1000.000000   30.000000   35.000000
# max    399.000000    399.000000  1000.000000   30.000000   51.000000

# %%
df['due_date'] = pd.to_datetime(df['due_date'])
df['effective_date'] = pd.to_datetime(df['effective_date'])
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender
# 0 2016-10-07   45  High School or Below    male
# 1 2016-10-07   33              Bechalor  female
# 2 2016-09-22   27               college    male
# 3 2016-10-08   28               college  female
# 4 2016-10-08   29               college    male

# %%
df['loan_status'].value_counts()
# Out:
# PAIDOFF       260
# COLLECTION     86
# Name: loan_status, dtype: int64

# %%
# !conda install -c anaconda seaborn -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/sylvaincarlevato/opt/anaconda3
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38hecd8cb5_0         2.9 MB
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following packages will be UPDATED:
#
#   conda                               4.10.1-py38hecd8cb5_1 --> 4.10.3-py38hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# conda-4.10.3         | 2.9 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import seaborn as sns

bins = np.linspace(df.Principal.min(), df.Principal.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'Principal', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
bins = np.linspace(df.age.min(), df.age.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'age', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
df['dayofweek'] = df['effective_date'].dt.dayofweek
bins = np.linspace(df.dayofweek.min(), df.dayofweek.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'dayofweek', bins=bins, ec="k")
g.axes[-1].legend()
plt.show()

# %%
df['weekend'] = df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below    male          3        0
# 1 2016-10-07   33              Bechalor  female          3        0
# 2 2016-09-22   27               college    male          3        0
# 3 2016-10-08   28               college  female          4        1
# 4 2016-10-08   29               college    male          4        1

# %%
df.groupby(['Gender'])['loan_status'].value_counts(normalize=True)
# Out:
# Gender  loan_status
# female  PAIDOFF        0.865385
#         COLLECTION     0.134615
# male    PAIDOFF        0.731293
#         COLLECTION     0.268707
# Name: loan_status, dtype: float64

# %%
df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below       0          3        0
# 1 2016-10-07   33              Bechalor       1          3        0
# 2 2016-09-22   27               college       0          3        0
# 3 2016-10-08   28               college       1          4        1
# 4 2016-10-08   29               college       0          4        1

# %%
df.groupby(['education'])['loan_status'].value_counts(normalize=True)
# Out:
# education             loan_status
# Bechalor              PAIDOFF        0.750000
#                       COLLECTION     0.250000
# High School or Below  PAIDOFF        0.741722
#                       COLLECTION     0.258278
# Master or Above       COLLECTION     0.500000
#                       PAIDOFF        0.500000
# college               PAIDOFF        0.765101
#                       COLLECTION     0.234899
# Name: loan_status, dtype: float64

# %%
df[['Principal','terms','age','Gender','education']].head()
# Out:
#    Principal  terms  age  Gender             education
# 0       1000     30   45       0  High School or Below
# 1       1000     30   33       1              Bechalor
# 2       1000     15   27       0               college
# 3       1000     30   28       1               college
# 4       1000     30   29       0               college

# %%
Feature = df[['Principal','terms','age','Gender','weekend']]
Feature = pd.concat([Feature,pd.get_dummies(df['education'])], axis=1)
Feature.drop(['Master or Above'], axis = 1,inplace=True)
Feature.head()
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %%
X = Feature
X[0:5]
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %%
y = df['loan_status'].values
y[0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %%
X= preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
# Out:
# array([[ 0.51578458,  0.92071769,  2.33152555, -0.42056004, -1.20577805,
#         -0.38170062,  1.13639374, -0.86968108],
#        [ 0.51578458,  0.92071769,  0.34170148,  2.37778177, -1.20577805,
#          2.61985426, -0.87997669, -0.86968108],
#        [ 0.51578458, -0.95911111, -0.65321055, -0.42056004, -1.20577805,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.48739188,  2.37778177,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.3215732 , -0.42056004,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (276, 8) (276,)
# Test set: (70, 8) (70,)

# %%
from sklearn.neighbors import KNeighborsClassifier
k = 6

neighK6 = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
neighK6
 
yhat = neighK6.predict(X_test)
yhat[0:5]

from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neighK6.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.8007246376811594
# Test set Accuracy:  0.7142857142857143

# %%
Ks = 10
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))

ConfustionMx = [];
for n in range(1,Ks):
    
    
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Nabors (K)')
plt.tight_layout()
plt.show()
print( "Best accuracy:", mean_acc.max(), "k=", mean_acc.argmax()+1)
# Out:
# Best accuracy: 0.7857142857142857 k= 7

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)
#Modelling
Tree = DecisionTreeClassifier(criterion="entropy", max_depth = 6)
Tree
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6)

# %%
Tree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6)

# %%
predTree = Tree.predict(X_testset)
print (predTree [0:5])
print (y_testset [0:5])

from sklearn import metrics
import matplotlib.pyplot as plt

print("Accuracy: ", metrics.accuracy_score(y_testset, predTree))


# !conda install -c conda-forge pydotplus -y
# !conda install -c conda-forge python-graphviz -y
from sklearn.externals.six import StringIO
import pydotplus
import matplotlib.image as mpimg
from sklearn import tree
# %matplotlib inline 
dot_data = StringIO()
filename = "loan.png"
featureNames = df.columns[0:8]
targetNames = df['loan_status'].unique().tolist()
out=tree.export_graphviz(Tree,feature_names=featureNames, out_file=dot_data, class_names= np.unique(y_trainset), filled=True,  special_characters=True,rotate=False)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png(filename)
img = mpimg.imread(filename)
plt.figure(figsize=(100, 200))
plt.imshow(img,interpolation='nearest')
# Out:
# ['PAIDOFF' 'PAIDOFF' 'PAIDOFF' 'PAIDOFF' 'PAIDOFF']
# ['PAIDOFF' 'PAIDOFF' 'COLLECTION' 'COLLECTION' 'PAIDOFF']
# Accuracy:  0.7019230769230769
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/sylvaincarlevato/opt/anaconda3
#
#   added / updated specs:
#     - pydotplus
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38h50d1736_0         3.1 MB  conda-forge
#     pydotplus-2.0.2            |             py_1          22 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   pydotplus          conda-forge/noarch::pydotplus-2.0.2-py_1
#   python_abi         conda-forge/osx-64::python_abi-3.8-2_cp38
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-4.10.3-py38hecd8cb5_0 --> conda-forge::conda-4.10.3-py38h50d1736_0
#
#
#
# Downloading and Extracting Packages
# python_abi-3.8       | 4 KB      | ##################################### | 100%
# pydotplus-2.0.2      | 22 KB     | ##################################### | 100%
# conda-4.10.3         | 3.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                                                                                                                                                                                               -failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - alabaster -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|3.4.*|>=3.7,<3.8.0a0']
#   - anaconda==2021.05 -> python[version='3.7.10|3.9.4|3.8.8',build='h88f2d9e_5|h88f2d9e_0']
#   - appdirs -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0']
#   - argon2-cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|>=3.5,<3.6.0a0|3.4.*|3.8.*|3.7.*|3.9.*',build='3_73_pypy|4_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|2_73_pypy|1_73_pypy|0_73_pypy']
#   - atomicwrites -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0']
#   - backports -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - bkcharts -> python=3.4
#   - bleach -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - brotlipy -> python[version='3.4.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.9.*|3.7.*|3.8.*',build='3_73_pypy|4_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|2_73_pypy|1_73_pypy|0_73_pypy']
#   - cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.9,<3.10.0a0|3.7.9|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9|>=3.5,<3.6.0a0|3.4.*',build='3_73_pypy|4_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|2_73_pypy|1_73_pypy|0_73_pypy']
#   - colorama -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - conda-env -> python[version='2.7.*|3.4.*|3.5.*']
#   - cryptography -> python[version='3.4.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.7.*|3.8.*|3.9.*|>=3.5|<=3.3',build='3_73_pypy|4_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|2_73_pypy|1_73_pypy|0_73_pypy']
#   - diff-match-patch -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - filelock -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - gevent -> python[version='3.4.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.8.*|3.9.*|3.7.*',build='3_73_pypy|4_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|2_73_pypy|1_73_pypy|0_73_pypy']
#   - glob2 -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - html5lib -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - imageio -> python[version='>=3.9,<3.10.0a0']
#   - imagesize -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0']
#   - intervaltree -> python[version='2.7.*|3.5.*|3.6.*']
#   - ipywidgets -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|3.4.*|>=3.7,<3.8.0a0']
#   - jdcal -> python[version='2.7.*|3.5.*|3.6.*|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - jupyter_console -> python[version='>=3.9,<3.10.0a0']
#   - more-itertools -> python[version='3.4.*|>=3.9,<3.10.0a0']
#   - navigator-updater -> python[version='2.7.*|3.5.*|3.6.*|3.4.*']
#   - olefile -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0']
#   - pycodestyle -> python[version='>=3.9,<3.10.0a0']
#   - pydotplus -> python[version='>=3.5,<3.6.0a0']
#   - pyflakes -> python[version='>=3.9,<3.10.0a0']
#   - pyopenssl -> python[version='>=3.9,<3.10.0a0']
#   - pyparsing -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - python-dateutil -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - qtpy -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|3.4.*|>=3.7,<3.8.0a0']
#   - singledispatch -> python[version='>=3.9,<3.10.0a0']
#   - sphinxcontrib-websupport -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - three-merge -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - tifffile -> python[version='>=3.9,<3.10.0a0']
#   - xmltodict -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0']
#   - zict -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - zope.event -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|3.4.*']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package bzip2 conflicts for:
# pyls-black -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# simplegeneric -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# filelock -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pip -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sphinx -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# soupsieve -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# libarchive -> bzip2[version='1.0.*|>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jupyter_console -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# appnope -> pypy3.6[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# prompt-toolkit -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# docutils -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# fsspec -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# html5lib -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# conda-token -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# wheel -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# click -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# anaconda-client -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pygments -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sphinxcontrib -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# matplotlib -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# nltk -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# decorator -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# send2trash -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# certifi -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pyflakes -> python[version='=2.7|>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# python-libarchive-c -> libarchive -> bzip2[version='1.0.*|>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# iniconfig -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# gevent -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# mypy_extensions -> pypy3.6[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# cycler -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# py -> python[version='>=2.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# async_generator -> python[version='>2.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# mkl_random -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# markupsafe -> pypy3.6[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pluggy -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# conda-build -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='1.0.*|>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# backports.tempfile -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pyerfa -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sphinxcontrib-websupport -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# astroid -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# brotlipy -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# bitarray -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pytest -> pypy3.7[version='>=7.3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# scipy -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# patsy -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# nbclient -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# psutil -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sqlalchemy -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jupyter -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# nest-asyncio -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# dask -> python[version='>=3.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# zipp -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# ujson -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pycodestyle -> python[version='=2.7|>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# python=3.8 -> bzip2[version='>=1.0.8,<2.0a0']
# cffi -> pypy3.7=7.3.5 -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# glib -> python= -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pydotplus -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# cytoolz -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# defusedxml -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jupyterlab_server -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# beautifulsoup4 -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pickleshare -> python[version='>=3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# conda-env -> python=3.5 -> bzip2[version='>=1.0.6,<2.0a0']
# sortedcontainers -> python[version='>=2.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# setuptools -> pypy3.6[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# python_abi -> python=3.8 -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# spyder -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# mpmath -> python[version='>=3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# typed-ast -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# parso -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pyls-spyder -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# black -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jupyter_core -> pypy3.6[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# gmpy2 -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# imageio -> python[version='>=3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# unicodecsv -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# mccabe -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# flask -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pyrsistent -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# notebook -> python[version='>=3.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# numpydoc -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# tblib -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# json5 -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# statsmodels -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# navigator-updater -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# lxml -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# packaging -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# glob2 -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# argh -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pyzmq -> pypy3.6[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# mkl_fft -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# networkx -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# applaunchservices -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# anyio -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pyqt -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# asn1crypto -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pycosat -> pypy3.7[version='>=7.3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# anaconda-project -> python[version='>=2.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# ruamel_yaml -> pypy3.7[version='>=7.3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# atomicwrites -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# llvmlite -> pypy3.6[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# nbformat -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# babel -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# xlwings -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pytables -> bzip2[version='1.0.*|>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# bottleneck -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sip -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# backports.functools_lru_cache -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# nbconvert -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# xlwt -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# dask-core -> python[version='>=3.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# numpy-base -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# cython -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# six -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sphinxcontrib-htmlhelp -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# rope -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# urllib3 -> python[version='<4.0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# nbclassic -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# python-dateutil -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pexpect -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# textdistance -> python[version='>=2.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# openpyxl -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# conda-verify -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# three-merge -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# distributed -> pypy3.7[version='>=7.3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# mkl-service -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# anaconda==2021.05 -> bzip2==1.0.8=h1de35cc_0
# tornado -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# importlib-metadata -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# colorama -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# future -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jupyter_client -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pillow -> pypy3.7[version='>=7.3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# tifffile -> imagecodecs[version='>=2021.4.28'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# watchdog -> pypy3.7[version='>=7.3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# numba -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# zict -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# threadpoolctl -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jupyterlab_widgets -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# diff-match-patch -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# intervaltree -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# python-graphviz -> python[version='>=3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# ipython -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# python-language-server -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# xlrd -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# appdirs -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# astropy -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# matplotlib-base -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jupyterlab -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# fastcache -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jsonschema -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jupyter-packaging -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sniffio -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# singledispatch -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# traitlets -> python[version='>=3.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jdcal -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# typing_extensions -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# rtree -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pytz -> python[version='>=3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pywavelets -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# ptyprocess -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# joblib -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pycparser -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# wurlitzer -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# anaconda==2021.05 -> libarchive==3.4.2=haa3ed63_0 -> bzip2[version='>=1.0.8,<2.0a0']
# yapf -> python[version='>=2.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pyparsing -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# path.py -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# greenlet -> pypy3.7[version='>=7.3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# clyent -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pydocstyle -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# anaconda-navigator -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# seaborn -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# testpath -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# attrs -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pep8 -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# partd -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# python-jsonrpc-server -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# terminado -> pypy3.7[version='>=7.3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# py-lief -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# ply -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# msgpack-python -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# qtconsole -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# conda-repo-cli -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# bleach -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# ipykernel -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# boto -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# zope.event -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# h5py -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# xlsxwriter -> python[version='>=2.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# xmltodict -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# prometheus_client -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# lazy-object-proxy -> pypy3.6[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pathspec -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# idna -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# bokeh -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# chardet -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# requests -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# more-itertools -> python[version='>=3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pandocfilters -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# snowballstemmer -> python[version='>=2'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pycurl -> pypy3.7[version='>=7.3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# alabaster -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# backports -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pyopenssl -> python[version='>=2.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# flake8 -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# entrypoints -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# scikit-image -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# toolz -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# cryptography -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# numexpr -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# werkzeug -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jinja2 -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# contextlib2 -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# backports.shutil_get_terminal_size -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# conda-content-trust -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# itsdangerous -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# python.app -> pypy3.7[version='>=7.3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# widgetsnbextension -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# backcall -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# appscript -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pylint -> python[version='>=3.6,<4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# path -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# isort -> python[version='>=3.6,<4.0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# qtawesome -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# nose -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# bkcharts -> python=3.6 -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sortedcollections -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jedi -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# ipython_genutils -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# sympy -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# autopep8 -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# conda[version='>=4.10.3'] -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# backports.weakref -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# webencodings -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# zope.interface -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pysocks -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# zope -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# imagesize -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# conda-package-handling -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jupyter_server -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# jupyterlab_pygments -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pathlib2 -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# mistune -> pypy3.7[version='>=7.3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# wrapt -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# mock -> pypy3.7[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# scikit-learn -> pypy3.6[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# qtpy -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# argon2-cffi -> python[version='>=3.6,<3.7.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# tqdm -> python[version='>=2.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# numpy -> pypy3.7[version='>=7.3.4'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# toml -> python[version='>=2.7'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# prompt_toolkit -> python[version='>=3.6'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pyyaml -> pypy3.6[version='>=7.3.3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# olefile -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# spyder-kernels -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pkginfo -> python[version='>=3'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# wcwidth -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# locket -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# et_xmlfile -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# keyring -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# regex -> pypy3.7[version='>=7.3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# cloudpickle -> python[version='>=3.5'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# multipledispatch -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# heapdict -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# ipywidgets -> python -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# pyodbc -> python[version='>=3.8,<3.9.0a0'] -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
#
# Package zlib conflicts for:
# typing_extensions -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# glob2 -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# multipledispatch -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# ipywidgets -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# testpath -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# cython -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# greenlet -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# jupyter -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# terminado -> pypy3.7[version='>=7.3.4'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# simplegeneric -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# lcms2 -> libtiff[version='>=4.2.0,<5.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pip -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# yapf -> python[version='>=2.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# pyyaml -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# ujson -> pypy3.7[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# jupyterlab_widgets -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# docutils -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# path.py -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# notebook -> python[version='>=3.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# colorama -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# json5 -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# ipykernel -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# libcurl -> libnghttp2[version='>=1.41.0,<2.0a0'] -> zlib[version='>=1.2.3']
# zope.event -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# nbclassic -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# wheel -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# alabaster -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# anaconda-client -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# prometheus_client -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# gmpy2 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# send2trash -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# cryptography -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# pathspec -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# jupyter-packaging -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='1.2.*|1.2.11|1.2.11.*|>=1.2.11,<1.3.0a0|1.2.8']
# ply -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# conda-repo-cli -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# navigator-updater -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.11.*|1.2.8']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# snowballstemmer -> python[version='>=2'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# pycparser -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# lazy-object-proxy -> pypy3.6[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# future -> pypy3.7[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# numexpr -> pypy3.7[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# werkzeug -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# ruamel_yaml -> pypy3.7[version='>=7.3.4'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# contextlib2 -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# openpyxl -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# three-merge -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# black -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# mock -> pypy3.7[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# xlrd -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# dask -> python[version='>=3.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# backcall -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# path -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# pylint -> python[version='>=3.6,<4'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# scikit-image -> pillow[version='>=4.3.0'] -> zlib[version='1.2.*|1.2.11|1.2.11.*|>=1.2.11,<1.3.0a0|1.2.8']
# libarchive -> libxml2[version='>=2.9.7,<2.10.0a0'] -> zlib==1.2.11
# python_abi -> python=3.9 -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# isort -> python[version='>=3.6,<4.0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# qtawesome -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# tk -> zlib[version='>=1.2.11,<1.3.0a0']
# nose -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# conda-content-trust -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# bkcharts -> python=3.6 -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# sortedcollections -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# jedi -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# sympy -> pypy3.7[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# autopep8 -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# nbconvert -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# llvmlite -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='1.2.*|1.2.11|1.2.8|1.2.11.*']
# webencodings -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# numpy-base -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# cytoolz -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# defusedxml -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# zope.interface -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# imagesize -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# conda-package-handling -> pypy3.7[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# python.app -> pypy3.7[version='>=7.3.4'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# pathlib2 -> pypy3.7[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.11.*|1.2.8']
# matplotlib -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='1.2.*|1.2.11|1.2.8|1.2.11.*']
# mpmath -> python[version='>=3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# anaconda==2021.05 -> zlib==1.2.11=h1de35cc_3
# jupyterlab_pygments -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# lxml -> libxml2[version='>=2.9.10,<2.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# python=3.8 -> zlib[version='>=1.2.11,<1.3.0a0']
# pyodbc -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# pyerfa -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# blosc -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0']
# hdf5 -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# singledispatch -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# toml -> python[version='>=2.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# asn1crypto -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# ipython_genutils -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# krb5 -> tk[version='>=8.6.10,<8.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# statsmodels -> pypy3.7[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# olefile -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# wrapt -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# pkginfo -> python[version='>=3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# diff-match-patch -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# jupyter_console -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# wcwidth -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# locket -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# keyring -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# mkl_fft -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# bleach -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# prompt_toolkit -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# matplotlib-base -> freetype[version='>=2.10.4,<3.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# zstd -> zlib[version='>=1.2.11,<1.3.0a0']
# conda-env -> python=3.5 -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.11.*|1.2.8']
# pep8 -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# heapdict -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# partd -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# matplotlib -> zlib[version='>=1.2.11,<1.3.0a0']
# python-graphviz -> graphviz[version='>=2.46.1'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# atomicwrites -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# sphinx -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# jupyterlab -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# pydocstyle -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# qtconsole -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# llvmlite -> zlib[version='>=1.2.11,<1.3.0a0']
# appnope -> pypy3.6[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# curl -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0']
# gettext -> libxml2[version='>=2.9.10,<2.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# joblib -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# xmltodict -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# jupyterlab_server -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# html5lib -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# python-jsonrpc-server -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# xlwt -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# click -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# pygments -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# python-dateutil -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# typed-ast -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# qt -> zlib[version='>=1.2.11,<1.3.0a0']
# libxml2 -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0']
# unicodecsv -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# more-itertools -> python[version='>=3.4'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# certifi -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# patsy -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# iniconfig -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# threadpoolctl -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# cycler -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# freetype -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0']
# libxslt -> libxml2[version='>=2.9.10,<2.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0']
# cloudpickle -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# sqlalchemy -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# py -> python[version='>=2.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# mkl_random -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# xlsxwriter -> python[version='>=2.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# jupyter_client -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# backports.tempfile -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# pillow -> zlib[version='1.2.*|1.2.11|1.2.11.*|>=1.2.11,<1.3.0a0|1.2.8']
# tifffile -> imagecodecs[version='>=2021.4.28'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# watchdog -> pypy3.7[version='>=7.3.4'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# zipp -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# backports -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# pluggy -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# python-language-server -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# sqlite -> zlib[version='>=1.2.11,<1.3.0a0']
# urllib3 -> python[version='<4.0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# rtree -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# fsspec -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# bitarray -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# widgetsnbextension -> pypy3.7[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# imageio -> pillow -> zlib[version='1.2.*|1.2.11|1.2.11.*|>=1.2.11,<1.3.0a0|1.2.8']
# zope -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# beautifulsoup4 -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# conda-verify -> pypy3.7[version='>=7.3.3'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# six -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# textdistance -> python[version='>=2.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# mistune -> pypy3.7[version='>=7.3.4'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*']
# ...
# spyder -> watchdog -> pyobjc-framework-cocoa[version='>=4.2.2']
#
# Package asn1crypto conflicts for:
# conda-content-trust -> cryptography -> asn1crypto[version='>=0.21.0']
# urllib3 -> cryptography[version='>=1.3.4'] -> asn1crypto[version='>=0.21.0']
# anaconda==2021.05 -> asn1crypto==1.4.0=py_0
# pyopenssl -> cryptography[version='>=2.8'] -> asn1crypto[version='>=0.21.0']
# cryptography -> asn1crypto[version='>=0.21.0']
#
# Package nest-asyncio conflicts for:
# nbconvert -> nbclient[version='>=0.5.0,<0.6.0'] -> nest-asyncio
# anaconda==2021.05 -> nest-asyncio==1.5.1=pyhd3eb1b0_0
# nbclient -> nest-asyncio
# anaconda==2021.05 -> nbclient==0.5.3=pyhd3eb1b0_0 -> nest-asyncio
#
# Package conda conflicts for:
# conda-build -> conda[version='>=4.1,<4.3|>=4.1|>=4.1,<4.4|>=4.3|>=4.5']
# anaconda-navigator -> conda-token -> conda[version='>=4.3']
# conda-token -> conda[version='>=4.3']
#
# Package jdcal conflicts for:
# openpyxl -> jdcal
# anaconda==2021.05 -> jdcal==1.4.1=py_0
# anaconda==2021.05 -> openpyxl==3.0.7=pyhd3eb1b0_0 -> jdcal
#
# Package jxrlib conflicts for:
# anaconda==2021.05 -> jxrlib==1.1=haf1e3a3_2
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> jxrlib[version='>=1.1,<1.2.0a0']
#
# Package llvmdev conflicts for:
# numba -> llvmlite[version='>=0.33.0,<0.34'] -> llvmdev=9.0
# llvmlite -> llvmdev=9.0
#
# Package isort conflicts for:
# anaconda==2021.05 -> pylint==2.7.4=py37hecd8cb5_1 -> isort[version='>=4.2.5,<6']
# pylint -> isort[version='>=4.2.5|>=4.2.5,<5|>=4.2.5,<6']
# anaconda==2021.05 -> isort==5.8.0=pyhd3eb1b0_0
# python-language-server -> pylint[version='>=2.5.0'] -> isort[version='>=4.2.5|>=4.2.5,<5|>=4.2.5,<6']
# spyder -> pylint[version='>=1.0'] -> isort[version='>=4.2.5|>=4.2.5,<5|>=4.2.5,<6']
#
# Package nss conflicts for:
# pyqt -> qt[version='>=5.12.9,<5.13.0a0'] -> nss[version='>=3.39,<4.0a0|>=3.47,<4.0a0|>=3.46,<4.0a0']
# qt -> nss[version='>=3.39,<4.0a0|>=3.47,<4.0a0|>=3.46,<4.0a0|>=3.45,<4.0a0']
#
# Package sphinxcontrib-htmlhelp conflicts for:
# anaconda==2021.05 -> sphinx==4.0.1=pyhd3eb1b0_0 -> sphinxcontrib-htmlhelp
# sphinx -> sphinxcontrib-htmlhelp
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-htmlhelp
# anaconda==2021.05 -> sphinxcontrib-htmlhelp==1.0.3=pyhd3eb1b0_0
# numpydoc -> sphinx -> sphinxcontrib-htmlhelp
#
# Package appdirs conflicts for:
# anaconda==2021.05 -> appdirs==1.4.4=py_0
# scikit-image -> pooch[version='>=1.3.0'] -> appdirs
# black -> appdirs
# prometheus_client -> twisted -> appdirs[version='>=1.4.0']
# pyls-black -> black -> appdirs
# anaconda==2021.05 -> black==19.10b0=py_0 -> appdirs
#
# Package watchdog conflicts for:
# anaconda==2021.05 -> watchdog==1.0.2[build='py37h9ed2024_1|py39h9ed2024_1|py38h9ed2024_1']
# anaconda==2021.05 -> spyder==4.2.5=py37hecd8cb5_0 -> watchdog[version='>=0.10.3,<2.0.0']
# spyder -> watchdog[version='>=0.10.3|>=0.10.3,<2.0.0']
#
# Package alabaster conflicts for:
# numpydoc -> sphinx -> alabaster[version='>=0.7,<0.8']
# sphinx -> alabaster[version='>=0.7,<0.8']
# anaconda==2021.05 -> sphinx==4.0.1=pyhd3eb1b0_0 -> alabaster[version='>=0.7,<0.8']
# spyder -> sphinx[version='>=0.6.6'] -> alabaster[version='>=0.7,<0.8']
# anaconda==2021.05 -> alabaster==0.7.12[build='py37_0|pyhd3eb1b0_0']
#
# Package py-lief conflicts for:
# conda-build -> py-lief
# anaconda==2021.05 -> py-lief==0.10.1[build='py38haf313ee_0|py37haf313ee_0|py39h23ab428_1']
#
# Package networkx conflicts for:
# anaconda==2021.05 -> scikit-image==0.18.1=py37hb2f4e1b_0 -> networkx[version='>=2.0']
# anaconda==2021.05 -> networkx==2.5=py_0
# scikit-image -> networkx[version='>=1.8,<2.0|>=1.8|>=2.0']
#
# Package three-merge conflicts for:
# spyder -> three-merge[version='>=0.1.1']
# anaconda==2021.05 -> spyder==4.2.5=py37hecd8cb5_0 -> three-merge[version='>=0.1.1']
# anaconda==2021.05 -> three-merge==0.1.1=pyhd3eb1b0_0
#
# Package websocket-client conflicts for:
# jupyterlab -> jupyter_server[version='>=1.4,<2'] -> websocket-client
# jupyter_server -> websocket-client
# jupyterlab_server -> jupyter_server[version='>=1.4,<2'] -> websocket-client
# nbclassic -> jupyter_server[version='>=1.8.0,<2.0.0'] -> websocket-client
#
# Package conda-pack conflicts for:
# anaconda-navigator -> anaconda-project -> conda-pack
# anaconda-project -> conda-pack
#
# Package libzopfli conflicts for:
# anaconda==2021.05 -> libzopfli==1.0.3=hb1e8313_0
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> libzopfli[version='>=1.0.3,<1.1.0a0']
#
# Package sphinxcontrib-qthelp conflicts for:
# anaconda==2021.05 -> sphinxcontrib-qthelp==1.0.3=pyhd3eb1b0_0
# anaconda==2021.05 -> sphinx==4.0.1=pyhd3eb1b0_0 -> sphinxcontrib-qthelp
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-qthelp
# numpydoc -> sphinx -> sphinxcontrib-qthelp
# sphinx -> sphinxcontrib-qthelp
#
# Package s3fs conflicts for:
# dask -> distributed[version='>=1.16.0'] -> s3fs[version='>=0.0.6|>=0.0.7|>=0.0.8']
# distributed -> s3fs[version='>=0.0.6|>=0.0.7|>=0.0.8']
#
# Package liblapack conflicts for:
# scipy -> blas=[build=openblas] -> liblapack[version='3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0',build='4_mkl|5_mkl|7_mkl|10_mkl|11_mkl|13_mkl|19_mkl|20_mkl|5_mkl|9_mkl|2_openblas|7_openblas|11_openblas|13_openblas|14_openblas|15_openblas|16_openblas|5_openblas|6_openblas|7_openblas|9_openblas|8_openblas|17_openblas|12_openblas|10_openblas|9_openblas|8_openblas|6_openblas|5_openblas|4_openblas|3_openblas|8_mkl|7_mkl|6_mkl|21_mkl|18_mkl|16_mkl|15_mkl|14_mkl|12_mkl|9_mkl|8_mkl|6_mkl']
# scipy -> liblapack[version='>=3.8.0,<4.0.0a0|>=3.8.0,<4.0a0']
#
# Package libblas conflicts for:
# scipy -> libcblas[version='>=3.8.0,<4.0a0'] -> libblas[version='3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0.*|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0|3.9.0.*',build='4_blis|4_mkl|5_openblas|5_mkl|6_blis|7_blis|7_openblas|7_mkl|8_blis|9_openblas|9_mkl|10_openblas|11_openblas|13_openblas|13_mkl|14_mkl|14_openblas|15_openblas|16_openblas|16_blis|19_mkl|21_mkl|0_blis|0_openblas|4_blis|4_mkl|5_openblas|6_blis|7_openblas|7_blis|8_blis|9_blis|9_mkl|9_openblas|8_mkl|8_openblas|7_mkl|6_mkl|6_openblas|5_mkl|5_blis|4_openblas|3_openblas|3_blis|2_openblas|2_blis|1_openblas|1_blis|20_mkl|18_mkl|17_openblas|16_mkl|15_mkl|15_blis|14_blis|13_blis|12_openblas|12_mkl|12_blis|11_mkl|11_blis|10_mkl|10_blis|9_blis|8_mkl|8_openblas|6_mkl|6_openblas|5_blis|4_openblas']
# scipy -> libblas[version='>=3.8.0,<4.0a0']
#
# Package libgfortran4 conflicts for:
# scipy -> libgfortran=4 -> libgfortran4
# scipy -> libgfortran4[version='>=7.5.0']
#
# Package ripgrep conflicts for:
# anaconda==2021.05 -> ripgrep==12.1.1=0
# conda-build -> ripgrep
#
# Package werkzeug conflicts for:
# anaconda==2021.05 -> flask==1.1.2=pyhd3eb1b0_0 -> werkzeug[version='>=0.15']
# flask -> werkzeug[version='>=0.14|>=0.15|>=2.0|>=0.7|>=0.7,<1.0.0']
# anaconda==2021.05 -> werkzeug==1.0.1=pyhd3eb1b0_0
#
# Package threadpoolctl conflicts for:
# nltk -> scikit-learn -> threadpoolctl[version='>=2.0.0']
# anaconda==2021.05 -> threadpoolctl==2.1.0=pyh5ca1d4c_0
# anaconda==2021.05 -> scikit-learn==0.24.1=py37hb2f4e1b_0 -> threadpoolctl
# scikit-learn -> threadpoolctl[version='>=2.0.0']
#
# Package mpi conflicts for:
# hdf5 -> openmpi[version='>=4.1,<4.2.0a0'] -> mpi==1.0[build='mpich|openmpi']
# h5py -> mpich[version='>=3.4.2,<4.0a0'] -> mpi==1.0[build='mpich|openmpi']
#
# Package conda-env conflicts for:
# conda-build -> conda[version='>=4.5'] -> conda-env[version='>=2.5|>=2.6']
# conda-token -> conda[version='>=4.3'] -> conda-env[version='>=2.6']
#
# Package anaconda-client conflicts for:
# anaconda==2021.05 -> anaconda-client==1.7.2[build='py39hecd8cb5_0|py37_0|py38_0']
# anaconda-navigator -> conda-repo-cli -> anaconda-client[version='>=1.7.2']
# anaconda-navigator -> anaconda-client[version='>=1.6|>=1.6.12|>=1.6.14']
# conda-repo-cli -> anaconda-client[version='>=1.7.2']
# anaconda==2021.05 -> anaconda-project==0.9.1=pyhd3eb1b0_1 -> anaconda-client
# anaconda-project -> anaconda-client
#
# Package mock conflicts for:
# anaconda==2021.05 -> pytables==3.6.1=py37h5bccee9_0 -> mock
# anaconda==2021.05 -> mock==4.0.3=pyhd3eb1b0_0
# pytables -> mock
#
# Package qdarkstyle conflicts for:
# anaconda==2021.05 -> qdarkstyle==2.8.1=py_0
# spyder -> qdarkstyle[version='3.0.2.*|>=2.8,<3.0|>=2.8|>=2.7']
# anaconda==2021.05 -> spyder==4.2.5=py37hecd8cb5_0 -> qdarkstyle[version='>=2.8,<3.0']
#
# Package defusedxml conflicts for:
# notebook -> nbconvert -> defusedxml
# nbconvert -> defusedxml
# anaconda==2021.05 -> nbconvert==6.0.7=py37_0 -> defusedxml
# jupyter -> nbconvert -> defusedxml
# anaconda==2021.05 -> defusedxml==0.7.1=pyhd3eb1b0_0
# jupyter_server -> nbconvert -> defusedxml
# spyder -> nbconvert[version='>=4.0'] -> defusedxml
#
# Package gettext conflicts for:
# anaconda==2021.05 -> glib==2.68.1=hdf23fa2_0 -> gettext[version='>=0.21.0,<1.0a0']
# dbus -> glib -> gettext[version='>=0.19.8.1,<1.0a0|>=0.21.0,<1.0a0']
# glib -> gettext[version='>=0.19.8.1,<1.0a0|>=0.21.0,<1.0a0']
# anaconda==2021.05 -> gettext==0.21.0=h7535e17_0
#
# Package typing-extensions conflicts for:
# astroid -> typing-extensions[version='>=3.7.4']
# pylint -> astroid[version='>=2.6.2,<2.7'] -> typing-extensions[version='>=3.7.4']
#
# Package jaraco.itertools conflicts for:
# zipp -> jaraco.itertools
# importlib-metadata -> zipp[version='>=0.5'] -> jaraco.itertools
# importlib_metadata -> zipp[version='>=0.5'] -> jaraco.itertools
#
# Package statsmodels conflicts for:
# anaconda==2021.05 -> statsmodels==0.12.2[build='py37h9ed2024_0|py39h9ed2024_0|py38h9ed2024_0']
# seaborn -> statsmodels[version='>=0.5.0|>=0.8.0']
#
# Package pyls-black conflicts for:
# anaconda==2021.05 -> spyder==4.2.5=py37hecd8cb5_0 -> pyls-black[version='>=0.4.6']
# spyder -> pyls-black[version='>=0.4.6']
# anaconda==2021.05 -> pyls-black==0.4.6=hd3eb1b0_0
#
# Package pep8 conflicts for:
# python-language-server -> autopep8 -> pep8[version='>=1.5.7']
# autopep8 -> pep8[version='>=1.5.7']
# anaconda==2021.05 -> pep8==1.7.1[build='py39hecd8cb5_0|py37_0|py38_0']
# spyder -> pep8
#
# Package python-lsp-server conflicts for:
# spyder -> pyls-spyder[version='>=0.3.2'] -> python-lsp-server[version='>=1.0.1']
# pyls-spyder -> python-lsp-server[version='>=1.0.1']
#
# Package python-pathlib2 conflicts for:
# pickleshare -> python-pathlib2
# ipython -> pickleshare -> python-pathlib2
# spyder -> pickleshare[version='>=0.4'] -> python-pathlib2
#
# Package liblief conflicts for:
# py-lief -> liblief[version='0.10.1|0.10.1|0.10.1|0.10.1|0.10.1|0.11.3|0.11.4|0.11.5|0.9.0|0.9.0|0.9.0|0.9.0|0.8.3',build='h2a1bed3_1|h2a1bed3_2|h23ab428_1|h2a1bed3_1|h3e78482_1|hb1e8313_2|he49afe7_0|hb1e8313_1|hb1e8313_0|h2a1bed3_0|h0a44026_0']
# conda-build -> py-lief -> liblief[version='0.10.1|0.10.1|0.10.1|0.10.1|0.10.1|0.11.3|0.11.4|0.11.5|0.9.0|0.9.0|0.9.0|0.9.0|0.8.3',build='h2a1bed3_1|h2a1bed3_2|h23ab428_1|h2a1bed3_1|h3e78482_1|hb1e8313_2|he49afe7_0|hb1e8313_1|hb1e8313_0|h2a1bed3_0|h0a44026_0']
# anaconda==2021.05 -> liblief==0.10.1[build='h0a44026_0|h23ab428_1']
#
# Package filelock conflicts for:
# anaconda==2021.05 -> filelock==3.0.12=pyhd3eb1b0_1
# conda-build -> filelock
#
# Package zfp conflicts for:
# anaconda==2021.05 -> zfp==0.5.5=h23ab428_6
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> zfp[version='>=0.5.5,<1.0a0']
#
# Package jupyterlab_launcher conflicts for:
# jupyterlab -> jupyterlab_launcher[version='<0.2|>=0.10.0,<0.11.0|>=0.11.2,<0.12.0|>=0.13.1,<0.14.0|>=0.6.0,<0.7.0|>=0.5.4,<0.6.0|>=0.5.4|>=0.4.0|>=0.3.0|>=0.2.3|>=0.11.0,<0.12.0']
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> jupyterlab_launcher[version='<0.2|>=0.10.0,<0.11.0|>=0.11.2,<0.12.0|>=0.13.1,<0.14.0|>=0.6.0,<0.7.0|>=0.5.4,<0.6.0|>=0.5.4|>=0.4.0|>=0.3.0|>=0.2.3|>=0.11.0,<0.12.0']
#
# Package curl conflicts for:
# pycurl -> curl[version='7.55.*|>=7.55.1,<8.0a0']
# anaconda==2021.05 -> curl==7.71.1=hb0a8c7a_1
#
# Package textdistance conflicts for:
# spyder -> textdistance[version='>=4.2.0']
# anaconda==2021.05 -> textdistance==4.2.1=pyhd3eb1b0_0
# anaconda==2021.05 -> spyder==4.2.5=py37hecd8cb5_0 -> textdistance[version='>=4.2.0']
#
# Package sphinxcontrib conflicts for:
# anaconda==2021.05 -> sphinxcontrib==1.0[build='py38_1|py39hecd8cb5_1|py37_1']
# sphinxcontrib-websupport -> sphinxcontrib
# anaconda==2021.05 -> sphinxcontrib-websupport==1.2.4=py_0 -> sphinxcontrib
# sphinx -> sphinxcontrib-websupport -> sphinxcontrib
#
# Package pkg-config conflicts for:
# glib -> pkg-config
# dbus -> glib -> pkg-config
#
# Package openblas conflicts for:
# scipy -> libblas[version='>=3.8.0,<4.0a0'] -> openblas[version='0.3.5.*|>=0.3.6,<0.3.7.0a0|>=0.2.15']
# scipy -> openblas[version='0.2.18.*|0.2.18|0.2.18.*|0.2.19|0.2.19.*|0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0']
#
# Package distributed conflicts for:
# anaconda==2021.05 -> distributed==2021.4.0[build='py38hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0']
# dask -> distributed[version='2021.4.1.*|2021.5.0.*|2021.5.1.*|2021.6.0.*|2021.6.1.*|2021.6.2.*|>=2021.4.1|>=2021.4.0|>=2021.3.1|>=2021.3.0|>=2021.2.0|>=2021.1.1|>=2021.1.0|>=2020.12.0|>=2.30.0|>=2.29.0|>=2.28.0|>=2.27.0|>=2.26.0|>=2.25.0|>=2.24.0|>=2.23.0|>=2.22.0|>=2.21.0|>=2.20.0|>=2.19.0|>=2.18.0|>=2.17.0|>=2.16.0|>=2.15.0|>=2.14.0|>=2.13.0|>=2.12.0|>=2.11.0|>=2.10.0|>=2.9.2|>=2.9.1|>=2.9.0|>=2.8.1|>=2.8.0|>=2.7.0|>=2.6.0|>=2.5.2|>=2.5.0|>=2.4.0|>=2.3.0|>=2.2.0|>=2|>=1.28.0|>=1.27.0|>=1.26.1|>=1.26.0|>=1.25.3|>=1.25.2|>=1.25.0|>=1.24.2|>=1.23.3|>=1.23.2|>=1.23.1|>=1.23.0|>=1.22.0|>=1.21.0|>=1.21.1|>=1.20.0|>=1.19.0|>=1.16.0|>=1.15.0|>=1.11.0']
# scikit-image -> dask[version='>=0.5'] -> distributed[version='2021.4.1.*|2021.5.0.*|2021.5.1.*|2021.6.0.*|2021.6.1.*|2021.6.2.*|>=2021.4.1|>=2021.4.0|>=2021.3.1|>=2021.3.0|>=2021.2.0|>=2021.1.1|>=2021.1.0|>=2020.12.0|>=2.30.0|>=2.29.0|>=2.28.0|>=2.27.0|>=2.26.0|>=2.25.0|>=2.24.0|>=2.23.0|>=2.22.0|>=2.21.0|>=2.20.0|>=2.19.0|>=2.18.0|>=2.17.0|>=2.16.0|>=2.15.0|>=2.14.0|>=2.13.0|>=2.12.0|>=2.11.0|>=2.10.0|>=2.9.2|>=2.9.1|>=2.9.0|>=2.8.1|>=2.8.0|>=2.7.0|>=2.6.0|>=2.5.2|>=2.5.0|>=2.4.0|>=2.3.0|>=2.2.0|>=2|>=1.28.0|>=1.27.0|>=1.26.1|>=1.26.0|>=1.25.3|>=1.25.2|>=1.25.0|>=1.24.2|>=1.23.3|>=1.23.2|>=1.23.1|>=1.23.0|>=1.22.0|>=1.21.0|>=1.21.1|>=1.20.0|>=1.19.0|>=1.16.0|>=1.15.0|>=1.11.0']
# anaconda==2021.05 -> dask==2021.4.0=pyhd3eb1b0_0 -> distributed[version='>=2021.4.0']
#
# Package path conflicts for:
# anaconda==2021.05 -> path.py==12.5.0=0 -> path
# anaconda==2021.05 -> path==15.1.2[build='py38hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0']
# path.py -> path[version='<13.2']
#
# Package anaconda-project conflicts for:
# anaconda-navigator -> anaconda-project[version='>=0.4']
# anaconda==2021.05 -> anaconda-project==0.9.1=pyhd3eb1b0_1
#
# Package giflib conflicts for:
# anaconda==2021.05 -> giflib==5.1.4=h1de35cc_1
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> giflib[version='>=5.1.4,<5.2.0a0']
# tifffile -> imagecodecs[version='>=2021.4.28'] -> giflib[version='>=5.1.4,<5.2.0a0|>=5.2.1,<5.3.0a0']
# libtiff -> libwebp -> giflib[version='>=5.1.4,<5.2.0a0|>=5.1.7,<5.1.8.0a0|>=5.2.1,<5.3.0a0']
#
# Package json5 conflicts for:
# anaconda==2021.05 -> json5==0.9.5=py_0
# anaconda==2021.05 -> jupyterlab_server==2.4.0=pyhd3eb1b0_0 -> json5
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> json5
# jupyterlab_server -> json5
#
# Package libaec conflicts for:
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> libaec[version='>=1.0.4,<2.0a0']
# anaconda==2021.05 -> libaec==1.0.4=hb1e8313_1
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-78da851bd1b7> in <module>
#      11 get_ipython().system('conda install -c conda-forge pydotplus -y')
#      12 get_ipython().system('conda install -c conda-forge python-graphviz -y')
# ---> 13 from sklearn.externals.six import StringIO
#      14 import pydotplus
#      15 import matplotlib.image as mpimg
#
# ModuleNotFoundError: No module named 'sklearn.externals.six'

# %%
df.dtypes
df = df[pd.to_numeric(df['education'], errors='coerce').notnull()]
df['education'] = df['education'].astype('int')
df.dtypes

from sklearn import svm
clf = svm.SVC(kernel='rbf')
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
yhat = clf.predict(X_test)
yhat [0:5]
from sklearn.metrics import classification_report, confusion_matrix
import itertools

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
cnf_matrix = confusion_matrix(y_test, yhat, labels=['PAIDOFF','COLLECTION'])
np.set_printoptions(precision=2)

print (classification_report(y_test, yhat))

plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['PAIDOFF','COLLECTION'],normalize= False,  title='Confusion matrix')

from sklearn.metrics import f1_score
f1_score(y_test, yhat, average='weighted')

from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
#               precision    recall  f1-score   support
#
#   COLLECTION       0.36      0.27      0.31        15
#      PAIDOFF       0.81      0.87      0.84        55
#
#     accuracy                           0.74        70
#    macro avg       0.59      0.57      0.57        70
# weighted avg       0.72      0.74      0.73        70
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-33-f625078acb23> in <module>
#      35 f1_score(y_test, yhat, average='weighted')
#      36
# ---> 37 from sklearn.metrics import jaccard_similarity_score
#      38 jaccard_similarity_score(y_test, yhat)
#
# ImportError: cannot import name 'jaccard_similarity_score' from 'sklearn.metrics' (/Users/sylvaincarlevato/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/__init__.py)

# %%
df = df[['loan_status', 'Principal', 'terms', 'effective_date', 'due_date', 'age', 'education', 'Gender']]
df['loan_status'] = df['loan_status'].astype('int')

from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LogR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LogR
# Out:
# Train set: (276, 8) (276,)
# Test set: (70, 8) (70,)
# LogisticRegression(C=0.01, solver='liblinear')

# %%
yhat = LogR.predict(X_test)
yhat
yhat_prob = LogR.predict_proba(X_test)
yhat_prob
# Out:
# array([[0.5 , 0.5 ],
#        [0.45, 0.55],
#        [0.31, 0.69],
#        [0.34, 0.66],
#        [0.32, 0.68],
#        [0.32, 0.68],
#        [0.49, 0.51],
#        [0.48, 0.52],
#        [0.34, 0.66],
#        [0.49, 0.51],
#        [0.34, 0.66],
#        [0.5 , 0.5 ],
#        [0.25, 0.75],
#        [0.34, 0.66],
#        [0.44, 0.56],
#        [0.26, 0.74],
#        [0.52, 0.48],
#        [0.3 , 0.7 ],
#        [0.5 , 0.5 ],
#        [0.32, 0.68],
#        [0.44, 0.56],
#        [0.49, 0.51],
#        [0.51, 0.49],
#        [0.47, 0.53],
#        [0.41, 0.59],
#        [0.51, 0.49],
#        [0.51, 0.49],
#        [0.37, 0.63],
#        [0.5 , 0.5 ],
#        [0.25, 0.75],
#        [0.47, 0.53],
#        [0.46, 0.54],
#        [0.46, 0.54],
#        [0.48, 0.52],
#        [0.39, 0.61],
#        [0.46, 0.54],
#        [0.5 , 0.5 ],
#        [0.29, 0.71],
#        [0.46, 0.54],
#        [0.45, 0.55],
#        [0.51, 0.49],
#        [0.32, 0.68],
#        [0.45, 0.55],
#        [0.51, 0.49],
#        [0.31, 0.69],
#        [0.5 , 0.5 ],
#        [0.47, 0.53],
#        [0.5 , 0.5 ],
#        [0.46, 0.54],
#        [0.46, 0.54],
#        [0.28, 0.72],
#        [0.47, 0.53],
#        [0.31, 0.69],
#        [0.49, 0.51],
#        [0.28, 0.72],
#        [0.25, 0.75],
#        [0.32, 0.68],
#        [0.43, 0.57],
#        [0.47, 0.53],
#        [0.34, 0.66],
#        [0.42, 0.58],
#        [0.33, 0.67],
#        [0.46, 0.54],
#        [0.53, 0.47],
#        [0.32, 0.68],
#        [0.49, 0.51],
#        [0.33, 0.67],
#        [0.42, 0.58],
#        [0.45, 0.55],
#        [0.32, 0.68]])

# %%
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
from sklearn.metrics import log_loss
log_loss(y_test, yhat_prob)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-36-24fc50f3c694> in <module>
# ----> 1 from sklearn.metrics import jaccard_similarity_score
#       2 jaccard_similarity_score(y_test, yhat)
#       3 from sklearn.metrics import log_loss
#       4 log_loss(y_test, yhat_prob)
#
# ImportError: cannot import name 'jaccard_similarity_score' from 'sklearn.metrics' (/Users/sylvaincarlevato/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/__init__.py)

# %%
from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-37-09a90985a266> in <module>
# ----> 1 from sklearn.metrics import jaccard_similarity_score
#       2 from sklearn.metrics import f1_score
#       3 from sklearn.metrics import log_loss
#
# ImportError: cannot import name 'jaccard_similarity_score' from 'sklearn.metrics' (/Users/sylvaincarlevato/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/__init__.py)

# %%
test_df = pd.read_csv("loan_test.csv")

# %%
test_df = pd.read_csv('loan_test.csv')
test_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           1             1     PAIDOFF       1000     30       9/8/2016
# 1           5             5     PAIDOFF        300      7       9/9/2016
# 2          21            21     PAIDOFF       1000     30      9/10/2016
# 3          24            24     PAIDOFF       1000     30      9/10/2016
# 4          35            35     PAIDOFF        800     15      9/11/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   50              Bechalor  female
# 1  9/15/2016   35       Master or Above    male
# 2  10/9/2016   43  High School or Below  female
# 3  10/9/2016   26               college    male
# 4  9/25/2016   29              Bechalor    male

# %%
X= preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
Y = test_df['loan_status'].values
Y[0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %%
yhatKNN=neigh.predict(X)
KNNJaccard = jaccard_similarity_score(y, yhatKNN)
KNNF1 = f1_score(y, yhatKNN, average='weighted')
print("Avg F1-score: %.2f" % KNNF1 )
print("KNN Jaccard Score: %.2f" % KNNJaccard)


yhatDEC = Tree.predict(X)
DTJaccard = jaccard_similarity_score(y, yhatDEC)
DTF1 = f1_score(y, yhatDEC, average='weighted')
print("Avg F1-score: %.2f" % DTF1 )
print("Decision Tree Jaccard Score: %.2f" % DTJaccard)

yhatSVM=clf.predict(X)
SVMJaccard = jaccard_similarity_score(y, yhatSVM)
SVMF1 = f1_score(y, yhatSVM, average='weighted')
print("Avg F1-score: %.2f" % SVMF1)
print("SVM Jaccard score: %.2f" % SVMJaccard)

yhatLOG = LogR.predict(X)
yhatLOGproba = LogR.predict_proba(X)
LogRJaccard = jaccard_similarity_score(y, yhatLOG)
LogRF1 = f1_score(y, yhatLOG, average='weighted')
Logloss = log_loss(y, yhatLOGproba)
print("LogLoss: : %.2f" % Logloss)
print("Avg F1-score: %.4f" % LogRF1)
print("LOG Jaccard score: %.4f" % LogRJaccard)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-dd57ff7add61> in <module>
#       1 yhatKNN=neigh.predict(X)
# ----> 2 KNNJaccard = jaccard_similarity_score(y, yhatKNN)
#       3 KNNF1 = f1_score(y, yhatKNN, average='weighted')
#       4 print("Avg F1-score: %.2f" % KNNF1 )
#       5 print("KNN Jaccard Score: %.2f" % KNNJaccard)
#
# NameError: name 'jaccard_similarity_score' is not defined
